# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn_pandas import DataFrameMapper, cross_val_score
from sklearn import preprocessing
from sklearn import decomposition
from sklearn import compose
from sklearn import pipeline
from sklearn import linear_model
from sklearn import svm
from sklearn import ensemble
from sklearn import naive_bayes
from sklearn import tree
from sklearn import svm
from sklearn import neighbors
from sklearn import feature_extraction

# %%
df_train = pd.read_csv(
    'data/train.csv', 
    usecols='Dates PdDistrict Address X Y Category'.split(),
    parse_dates=['Dates']
)
df_train.head()
# Out:
#                 Dates        Category PdDistrict                    Address  \
# 0 2015-05-13 23:53:00        WARRANTS   NORTHERN         OAK ST / LAGUNA ST
# 1 2015-05-13 23:53:00  OTHER OFFENSES   NORTHERN         OAK ST / LAGUNA ST
# 2 2015-05-13 23:33:00  OTHER OFFENSES   NORTHERN  VANNESS AV / GREENWICH ST
# 3 2015-05-13 23:30:00   LARCENY/THEFT   NORTHERN   1500 Block of LOMBARD ST
# 4 2015-05-13 23:30:00   LARCENY/THEFT       PARK  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# 4 -122.438738  37.771541

# %%
vec = feature_extraction.text.CountVectorizer()

# %%
addresses = vec.fit_transform(df_train['Address'])

# %%
addresses
# Out:
# <878049x2141 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3928818 stored elements in Compressed Sparse Row format>

# %%
vec.get_feature_names()
# Out:
# ['100',
#  '1000',
#  '101',
#  '10th',
#  '1100',
#  '11th',
#  '1200',
#  '12th',
#  '1300',
#  '13th',
#  '1400',
#  '14th',
#  '1500',
#  '15th',
#  '1600',
#  '16th',
#  '1700',
#  '17th',
#  '1800',
#  '18th',
#  '1900',
#  '19th',
#  '1st',
#  '200',
#  '2000',
#  '20th',
#  '2100',
#  '21st',
#  '2200',
#  '22nd',
#  '2300',
#  '23rd',
#  '2400',
#  '24th',
#  '2500',
#  '25th',
#  '2600',
#  '26th',
#  '2700',
#  '27th',
#  '280',
#  '2800',
#  '28th',
#  '2900',
#  '29th',
#  '2nd',
#  '300',
#  '3000',
#  '30th',
#  '3100',
#  '31st',
#  '3200',
#  '32nd',
#  '3300',
#  '33rd',
#  '3400',
#  '34th',
#  '3500',
#  '35th',
#  '3600',
#  '36th',
#  '3700',
#  '37th',
#  '3800',
#  '38th',
#  '3900',
#  '39th',
#  '3rd',
#  '400',
#  '4000',
#  '40th',
#  '4100',
#  '41st',
#  '4200',
#  '42nd',
#  '4300',
#  '43rd',
#  '4400',
#  '44th',
#  '4500',
#  '45th',
#  '4600',
#  '46th',
#  '4700',
#  '47th',
#  '4800',
#  '48th',
#  '4900',
#  '4th',
#  '500',
#  '5000',
#  '5100',
#  '5200',
#  '5300',
#  '5400',
#  '5500',
#  '5600',
#  '5700',
#  '5800',
#  '5900',
#  '5th',
#  '5thstnorth',
#  '600',
#  '6000',
#  '6100',
#  '6200',
#  '6300',
#  '6400',
#  '6500',
#  '6600',
#  '6700',
#  '6800',
#  '6900',
#  '6th',
#  '700',
#  '7000',
#  '7100',
#  '7200',
#  '7300',
#  '7400',
#  '7500',
#  '7600',
#  '7700',
#  '7800',
#  '7900',
#  '7th',
#  '7thstnorth',
#  '80',
#  '800',
#  '8000',
#  '8100',
#  '8200',
#  '8300',
#  '8th',
#  '900',
#  '9th',
#  'abbey',
#  'acadia',
#  'acevedo',
#  'acton',
#  'ada',
#  'adair',
#  'adams',
#  'addison',
#  'adler',
#  'admiral',
#  'aerial',
#  'agnon',
#  'agua',
#  'ahern',
#  'al',
#  'alabama',
#  'aladdin',
#  'alameda',
#  'alana',
#  'albatross',
#  'alberta',
#  'albion',
#  'alder',
#  'alemany',
#  'alert',
#  'aleso',
#  'alhambra',
#  'alice',
#  'allen',
#  'allison',
#  'allston',
#  'alma',
#  'almaden',
#  'aloha',
#  'alpha',
#  'alpine',
#  'alta',
#  'altamar',
#  'alto',
#  'alton',
#  'alvarado',
#  'alviso',
#  'amador',
#  'amazon',
#  'amber',
#  'ambrose',
#  'ames',
#  'amethyst',
#  'amherst',
#  'ana',
#  'anderson',
#  'andover',
#  'andreas',
#  'ankeny',
#  'annapolis',
#  'annie',
#  'anselmo',
#  'anson',
#  'anthony',
#  'antonio',
#  'anza',
#  'anzavista',
#  'apollo',
#  'apparel',
#  'appleton',
#  'approach',
#  'aptos',
#  'aquavista',
#  'arago',
#  'arballo',
#  'arbol',
#  'arbor',
#  'arch',
#  'arco',
#  'ardath',
#  'ardenwood',
#  'arelious',
#  'arellano',
#  'argent',
#  'argonaut',
#  'arguello',
#  'arkansas',
#  'arleta',
#  'arlington',
#  'armory',
#  'armstrong',
#  'arnold',
#  'arroyo',
#  'arthur',
#  'ash',
#  'ashbury',
#  'ashton',
#  'aspen',
#  'atalaya',
#  'athens',
#  'atoll',
#  'auburn',
#  'august',
#  'augusta',
#  'austin',
#  'av',
#  'avalon',
#  'avenue',
#  'avery',
#  'avila',
#  'aztec',
#  'bache',
#  'bacon',
#  'baden',
#  'badger',
#  'baker',
#  'balance',
#  'balboa',
#  'balceta',
#  'baldwin',
#  'balhi',
#  'balmy',
#  'baltimore',
#  'banbury',
#  'bancroft',
#  'banks',
#  'bannam',
#  'bannecker',
#  'bannock',
#  'barbara',
#  'barcelona',
#  'barneveld',
#  'bartlett',
#  'bartol',
#  'bass',
#  'battery',
#  'bautista',
#  'bay',
#  'bayside',
#  'baysidevillage',
#  'bayview',
#  'baywood',
#  'bdry',
#  'beach',
#  'beachmont',
#  'beacon',
#  'beale',
#  'beatrice',
#  'beaumont',
#  'beaver',
#  'beckett',
#  'beeman',
#  'behr',
#  'beideman',
#  'belcher',
#  'belden',
#  'belgrave',
#  'bell',
#  'bella',
#  'bellair',
#  'bellavista',
#  'belle',
#  'bellevue',
#  'belmont',
#  'belvedere',
#  'bemis',
#  'benito',
#  'bennett',
#  'bennington',
#  'benton',
#  'bepler',
#  'bergen',
#  'berkeley',
#  'berkshire',
#  'bernal',
#  'bernalhts',
#  'bernard',
#  'bernice',
#  'berry',
#  'bertha',
#  'bertieminor',
#  'bertita',
#  'berwick',
#  'bessie',
#  'beulah',
#  'beverly',
#  'bierce',
#  'birch',
#  'birchwood',
#  'bird',
#  'bishop',
#  'bl',
#  'blackstone',
#  'blair',
#  'blake',
#  'blanche',
#  'blanken',
#  'block',
#  'bluxome',
#  'blvd',
#  'blythdale',
#  'boardman',
#  'bob',
#  'bocana',
#  'bonifacio',
#  'bonita',
#  'bonview',
#  'boom',
#  'borica',
#  'bosworth',
#  'boutwell',
#  'bowdoin',
#  'bowling',
#  'bowlinggreen',
#  'bowman',
#  'boylston',
#  'bradford',
#  'brady',
#  'brannan',
#  'brant',
#  'brazil',
#  'breen',
#  'brenham',
#  'brentwood',
#  'bretharte',
#  'brewster',
#  'bridge',
#  'bridgeview',
#  'bright',
#  'brighton',
#  'britton',
#  'broad',
#  'broadmoor',
#  'broadway',
#  'broderick',
#  'bromley',
#  'brompton',
#  'bronte',
#  'brook',
#  'brookdale',
#  'brooklyn',
#  'brosnan',
#  'brotherhood',
#  'bruce',
#  'brumiss',
#  'bruno',
#  'brunswick',
#  'brush',
#  'brussels',
#  'bryant',
#  'bucareli',
#  'buchanan',
#  'buckingham',
#  'buena',
#  'buenavistaeast',
#  'buenavistawest',
#  'bufano',
#  'burke',
#  'burlwood',
#  'burnett',
#  'burnham',
#  'burns',
#  'burnside',
#  'burr',
#  'burritt',
#  'burrows',
#  'bush',
#  'butte',
#  'byron',
#  'byxbee',
#  'cabrillo',
#  'cadell',
#  'caine',
#  'caire',
#  'caledonia',
#  'calgary',
#  'calhoun',
#  'california',
#  'cambon',
#  'cambridge',
#  'camellia',
#  'cameo',
#  'cameron',
#  'camino',
#  'camp',
#  'campbell',
#  'campton',
#  'canyon',
#  'capistrano',
#  'capitol',
#  'capp',
#  'capra',
#  'card',
#  'cardenas',
#  'cargo',
#  'carl',
#  'carlos',
#  'carmel',
#  'carmelita',
#  'carnelian',
#  'carolina',
#  'carpenter',
#  'carr',
#  'carrie',
#  'carrizal',
#  'carroll',
#  'carson',
#  'carter',
#  'carthy',
#  'carver',
#  'casa',
#  'cascade',
#  'caselli',
#  'cashmere',
#  'casitas',
#  'cassandra',
#  'castelo',
#  'castenada',
#  'castillo',
#  'castle',
#  'castlemanor',
#  'castro',
#  'cayuga',
#  'cecilia',
#  'cedar',
#  'cedro',
#  'central',
#  'century',
#  'ceres',
#  'cerritos',
#  'cervantes',
#  'cesar',
#  'chabot',
#  'chain',
#  'chainoflakes',
#  'chancery',
#  'channel',
#  'chapman',
#  'charles',
#  'charlton',
#  'charter',
#  'charteroak',
#  'chase',
#  'chatham',
#  'chattanooga',
#  'chaves',
#  'chavez',
#  'chenery',
#  'cherry',
#  'chesley',
#  'chester',
#  'chestnut',
#  'chicago',
#  'child',
#  'chilton',
#  'chinabasin',
#  'christmas',
#  'christmastreept',
#  'christopher',
#  'chula',
#  'chumasero',
#  'church',
#  'cielito',
#  'circular',
#  'cityview',
#  'clairview',
#  'clara',
#  'claremont',
#  'clarence',
#  'clarendon',
#  'clarion',
#  'claude',
#  'clay',
#  'clayton',
#  'clearfield',
#  'clearview',
#  'cleary',
#  'clement',
#  'clementina',
#  'cleo',
#  'cleorand',
#  'cleveland',
#  'cliff',
#  'clifford',
#  'clinton',
#  'clintonpark',
#  'clipper',
#  'clover',
#  'club',
#  'clyde',
#  'codman',
#  'cohen',
#  'colby',
#  'cole',
#  'coleridge',
#  'colin',
#  'colinpkellyjr',
#  'college',
#  'collingwood',
#  'collins',
#  'colon',
#  'colonial',
#  'colton',
#  'columbia',
#  'columbiasquare',
#  'columbus',
#  'colusa',
#  'commer',
#  'commercial',
#  'commonwealth',
#  'concord',
#  'congdon',
#  'congo',
#  'conkling',
#  'connecticut',
#  'conrad',
#  'conservatory',
#  'constanso',
#  'conte',
#  'converse',
#  'cook',
#  'cooper',
#  'cora',
#  'coral',
#  'corbett',
#  'corbin',
#  'cordelia',
#  'cordova',
#  'cornwall',
#  'corona',
#  'cortes',
#  'cortland',
#  'corwin',
#  'cosmo',
#  'coso',
#  'costa',
#  'cottage',
#  'cotter',
#  'country',
#  'countryclub',
#  'coventry',
#  'cr',
#  'cragmont',
#  'crags',
#  'crane',
#  'cranleigh',
#  'craut',
#  'creek',
#  'crescent',
#  'crescio',
#  'crespi',
#  'cresta',
#  'crestavista',
#  'crestlake',
#  'crestline',
#  'crestmont',
#  'crisp',
#  'cross',
#  'crossover',
#  'crown',
#  'cruz',
#  'crystal',
#  'ct',
#  'cuesta',
#  'culebra',
#  'cumberland',
#  'cunningham',
#  'curtis',
#  'cushman',
#  'custer',
#  'cutler',
#  'cuvier',
#  'cypress',
#  'cyril',
#  'cyrus',
#  'daggett',
#  'dakota',
#  'dalewood',
#  'daniel',
#  'danielburnham',
#  'danton',
#  'danvers',
#  'darien',
#  'darrell',
#  'dartmouth',
#  'dashiell',
#  'davidson',
#  'davis',
#  'dawnview',
#  'dawson',
#  'day',
#  'de',
#  'dearborn',
#  'deboom',
#  'decatur',
#  'decker',
#  'dedman',
#  'deforest',
#  'deharo',
#  'dehon',
#  'del',
#  'delancey',
#  'delano',
#  'delgado',
#  'dellbrook',
#  'delmar',
#  'delmonte',
#  'delong',
#  'delsur',
#  'delta',
#  'delvale',
#  'deming',
#  'demontfort',
#  'denslowe',
#  'derby',
#  'desmond',
#  'desoto',
#  'detroit',
#  'devonshire',
#  'dewey',
#  'dewolf',
#  'diamond',
#  'diamondheights',
#  'diana',
#  'diaz',
#  'dichiera',
#  'diego',
#  'digby',
#  'divisadero',
#  'division',
#  'dodge',
#  'dolores',
#  'dolphin',
#  'donahue',
#  'donner',
#  'dorado',
#  'dorantes',
#  'dorcas',
#  'dorchester',
#  'dore',
#  'doric',
#  'dorland',
#  'dorman',
#  'dormitory',
#  'doublerock',
#  'douglass',
#  'dow',
#  'downey',
#  'dr',
#  'drake',
#  'drumm',
#  'dublin',
#  'duboce',
#  'dukes',
#  'duncan',
#  'duncombe',
#  'dunnes',
#  'dunshee',
#  'dunsmuir',
#  'dwight',
#  'dyke',
#  'eagle',
#  'earl',
#  'east',
#  'eastman',
#  'eastwood',
#  'eaton',
#  'ecker',
#  'eddy',
#  'edgar',
#  'edgehill',
#  'edgewood',
#  'edinburgh',
#  'edith',
#  'edna',
#  'edward',
#  'egbert',
#  'el',
#  'elcaminodelmar',
#  'elgin',
#  'elginpark',
#  'elim',
#  'elizabeth',
#  'elk',
#  'ellert',
#  'ellington',
#  'elliot',
#  'ellis',
#  'ellsworth',
#  'elm',
#  'elmhurst',
#  'elmira',
#  'elmirasol',
#  'elmo',
#  'elmwood',
#  'elplazuela',
#  'elsereno',
#  'elsie',
#  'elverano',
#  'elwood',
#  'embarcadero',
#  'embarcaderonorth',
#  'embarcaderosouth',
#  'emerson',
#  'emery',
#  'emmett',
#  'encanto',
#  'encline',
#  'enterprise',
#  'entrada',
#  'erie',
#  'ervine',
#  'escolta',
#  'escondido',
#  'esmeralda',
#  'espanola',
#  'esquina',
#  'essex',
#  'estero',
#  'eucalyptus',
#  'euclid',
#  'eugenia',
#  'eureka',
#  'evans',
#  'evelyn',
#  'everglade',
#  'everson',
#  'ewing',
#  'ex',
#  'excelsior',
#  'executive',
#  'executivepark',
#  'exeter',
#  'expwy',
#  'fair',
#  'fairfax',
#  'fairfield',
#  'fairmount',
#  'fairoaks',
#  'faith',
#  'fallon',
#  'falmouth',
#  'fanning',
#  'farallones',
#  'farnsworth',
#  'farnum',
#  'farragut',
#  'farview',
#  'faxon',
#  'fe',
#  'federal',
#  'felipe',
#  'felix',
#  'fell',
#  'fella',
#  'felton',
#  'ferlinghetti',
#  'fern',
#  'fernando',
#  'fernwood',
#  'fielding',
#  'filbert',
#  'fillmore',
#  'fitch',
#  'fitzgerald',
#  'flint',
#  'flood',
#  'flora',
#  'florence',
#  'florentine',
#  'florida',
#  'flournoy',
#  'flower',
#  'foerster',
#  'folsom',
#  'font',
#  'fontinella',
#  'foote',
#  'ford',
#  'forest',
#  'forestknolls',
#  'forestside',
#  'forestview',
#  'fortuna',
#  'fountain',
#  'fowler',
#  'france',
#  'francis',
#  'francisco',
#  'francois',
#  'franconia',
#  'frank',
#  'franklin',
#  'fratessa',
#  'frederick',
#  'fredson',
#  'freelon',
#  'freeway',
#  'fremont',
#  'fresno',
#  'friendship',
#  'front',
#  'fuente',
#  'fulton',
#  'funston',
#  'gabilan',
#  'gabriel',
#  'gaiser',
#  'galewood',
#  'galilee',
#  'galindo',
#  'gallagher',
#  'galvez',
#  'gambier',
#  'garces',
#  'garcia',
#  'garden',
#  'gardenside',
#  'garfield',
#  'garlington',
#  'garrison',
#  'gate',
#  'gates',
#  'gateview',
#  'gaven',
#  'gaviota',
#  'geary',
#  'gellert',
#  'genebern',
#  'geneva',
#  'gennesee',
#  'genoa',
#  'george',
#  'gerke',
#  'germain',
#  'germania',
#  'getz',
#  'gg',
#  'ggbridge',
#  'ggbridgeapproach',
#  'giants',
#  'gibb',
#  'gilbert',
#  'gillette',
#  'gilman',
#  'gilroy',
#  'girard',
#  'gladeview',
#  'gladstone',
#  'gladys',
#  'glenbrook',
#  'glendale',
#  'glenview',
#  'gloria',
#  'glover',
#  'godeus',
#  'goethe',
#  'goettingen',
#  'gold',
#  'golden',
#  'goldmine',
#  'goleta',
#  'gonzalez',
#  'gordon',
#  'gorham',
#  'gough',
#  'gould',
#  'grace',
#  'grafton',
#  'granada',
#  'grand',
#  'grande',
#  'grandview',
#  'grant',
#  'granville',
#  'grattan',
#  'graystone',
#  'great',
#  'green',
#  'greenview',
#  'greenwich',
#  'greenwood',
#  'griffith',
#  'grijalva',
#  'grove',
#  'guerrero',
#  'guttenberg',
#  'guy',
#  'hahn',
#  'haight',
#  'hale',
#  'hallam',
#  'halleck',
#  'hamerton',
#  'hamilton',
#  'hammett',
#  'hampshire',
#  'hancock',
#  'hangah',
#  'hanover',
#  'harbor',
#  'hardie',
#  'harding',
#  'hare',
#  'harkness',
#  'harlan',
#  'harlow',
#  'harney',
#  'haro',
#  'harold',
#  'harper',
#  'harriet',
#  'harrington',
#  'harris',
#  'harrison',
#  'harry',
#  'hartford',
#  'harvard',
#  'hastings',
#  'hattie',
#  'havelock',
#  'havens',
#  'havenside',
#  'hawes',
#  'hawkins',
#  'hawthorne',
#  'hayes',
#  'hazelwood',
#  'head',
#  'hearst',
#  'heather',
#  'heights',
#  'helen',
#  'helena',
#  'hemlock',
#  'hemway',
#  'henry',
#  'henryadams',
#  'herbst',
#  'hermann',
#  'hernandez',
#  'heron',
#  'hester',
#  'heyman',
#  'hickory',
#  'hidalgo',
#  'high',
#  'highland',
#  'higuera',
#  'hiliritas',
#  'hill',
#  'hillcrest',
#  'hillpoint',
#  'hillview',
#  'hillway',
#  'hilton',
#  'himmelmann',
#  'hinkley',
#  'hobart',
#  'hoff',
#  'hoffman',
#  'holladay',
#  'hollis',
#  'hollister',
#  'holloway',
#  'holly',
#  'hollypark',
#  'hollywood',
#  'holyoke',
#  ...]
